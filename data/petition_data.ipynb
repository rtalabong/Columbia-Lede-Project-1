# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
df = pd.read_excel('uscis_data_clean1.xlsx')

# %%
na_values = ['D', 'H']

# %%
df.shape
# Out:
# (61, 9)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#   Category and Form Number   Based  \
# 0                   I-129F  Family
# 1                    I-130  Family
# 2                    I-600  Family
# 3                   I-601A  Family
# 4                    I-751  Family
#
#                                          Description  Forms Received Approved  \
# 0                       Petition for Alien Fiancé(e)           20655    32357
# 1                        Petition for Alien Relative          507827   349266
# 2  Petition to Classify Orphan as an Immediate Re...             389      398
# 3  Application for Provisional Unlawful Presence ...           18249    29106
# 4         Petition to Remove Conditions on Residence           60059    51146
#
#   Denied Total Completions  Pending  Processing Time
# 0   5689             38046    30137         8.547936
# 1  50131            399397  2109145        11.572590
# 2    105               503      561         4.208215
# 3   3775             32881   130009        41.358859
# ...

# %%
family_based = df[df['Based']=='Family']

# %%
df.groupby('Based').sum('Pending').reset_index()
# Out:
#                          Based  Forms Received  Processing Time
# 0  Citizenship and Nationality          573475        19.462992
# 1                   Employment         2767194       149.835452
# 2                       Family          608401        94.191678
# 3                 Humanitarian         1050286       100.356054
# 4   Lawful Permanent Residence          511911        57.978019
# 5                        Other          976502       161.375166
# 6                 Supplemental          243996         0.000000

# %%
df.sort_values(by='Processing Time', ascending =False)
# Out:
#    Category and Form Number                        Based  \
# 53                    I-193                        Other
# 33                    I-918                 Humanitarian
# 8                     I-526                   Employment
# 3                    I-601A                       Family
# 15                    I-829                   Employment
# 4                     I-751                       Family
# 57                  Waivers                        Other
# 16                    I-924                   Employment
# 38                    I-485   Lawful Permanent Residence
# 49                    I-131                        Other
# 18                    I-956                   Employment
# 37                    I-485   Lawful Permanent Residence
# 32                    I-914                 Humanitarian
# 1                     I-130                       Family
# 34                    I-929                 Humanitarian
# ...

# %%
selected_columns = df[['Category and Form Number', 'Processing Time']]

# %%
selected_columns.to_csv('processing_times.csv', index=False)
